# %%
import pandas as pd

# %% [markdown]
# ```bash
#
# pip install sqlalchemy psycopg2-binary
#
# ```

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi",echo = False)

# %%
engine.connect()
con = engine.raw_connection()

# %%
query = """ 
SELECT 1 as number;
"""
pd.read_sql(query, con=con)
# Out:
# /tmp/ipykernel_10642/1249852608.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, con=con)
#    number
# 0       1

# %%
query = """ 
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND
    schemaname != 'information_schema';
"""
pd.read_sql(query, con=con)
# Out:
# /tmp/ipykernel_10642/3193516512.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, con=con)
#   schemaname   tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  table_name       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
df = pd.read_parquet("yellow_tripdata_2024-01.parquet")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2964624 entries, 0 to 2964623
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# memory usage: 395.8+ MB

# %%
df = df.head(100)

# %%
df.to_sql('table_name', engine)
# Out:
# 100

# %%
query = """ 
SELECT *
FROM table_name
LIMIT 10;
"""
pd.read_sql(query, con=con)
# Out:
# /tmp/ipykernel_10642/168714908.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, con=con)
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         2  2024-01-01 00:57:55   2024-01-01 01:17:43
# 1      1         1  2024-01-01 00:03:00   2024-01-01 00:09:36
# 2      2         1  2024-01-01 00:17:06   2024-01-01 00:35:01
# 3      3         1  2024-01-01 00:36:38   2024-01-01 00:44:56
# 4      4         1  2024-01-01 00:46:51   2024-01-01 00:52:57
# 5      5         1  2024-01-01 00:54:08   2024-01-01 01:26:31
# 6      6         2  2024-01-01 00:49:44   2024-01-01 01:15:47
# 7      7         1  2024-01-01 00:30:40   2024-01-01 00:58:40
# 8      8         2  2024-01-01 00:26:01   2024-01-01 00:54:12
# 9      9         2  2024-01-01 00:28:08   2024-01-01 00:29:16
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           1.72         1.0                  N
# 1              1.0           1.80         1.0                  N
# 2              1.0           4.70         1.0                  N
# 3              1.0           1.40         1.0                  N
# 4              1.0           0.80         1.0                  N
# 5              1.0           4.70         1.0                  N
# 6              2.0          10.82         1.0                  N
# 7              0.0           3.00         1.0                  N
# 8              1.0           5.44         1.0                  N
# 9              1.0           0.04         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           186            79             2         17.7    1.0      0.5
# 1           140           236             1         10.0    3.5      0.5
# 2           236            79             1         23.3    3.5      0.5
# 3            79           211             1         10.0    3.5      0.5
# 4           211           148             1          7.9    3.5      0.5
# 5           148           141             1         29.6    3.5      0.5
# 6           138           181             1         45.7    6.0      0.5
# 7           246           231             2         25.4    3.5      0.5
# 8           161           261             2         31.0    1.0      0.5
# 9           113           113             2          3.0    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        0.00           0.0                    1.0         22.70
# 1        3.75           0.0                    1.0         18.75
# 2        3.00           0.0                    1.0         31.30
# 3        2.00           0.0                    1.0         17.00
# 4        3.20           0.0                    1.0         16.10
# 5        6.90           0.0                    1.0         41.50
# 6       10.00           0.0                    1.0         64.95
# 7        0.00           0.0                    1.0         30.40
# 8        0.00           0.0                    1.0         36.00
# 9        0.00           0.0                    1.0          8.00
#
#    congestion_surcharge  Airport_fee
# 0                   2.5         0.00
# 1                   2.5         0.00
# 2                   2.5         0.00
# 3                   2.5         0.00
# 4                   2.5         0.00
# 5                   2.5         0.00
# 6                   0.0         1.75
# 7                   2.5         0.00
# 8                   2.5         0.00
# 9                   2.5         0.00

# %%
import argparse

# %%
parser = argparse.ArgumentParser(description='Process some integers.')

# %%
parser.add_argument('--user', help="user name for postgres")
parser.add_argument('--password', help="password for postgres")
parser.add_argument('--host', help="host for postgres")
parser.add_argument('--port', help="port for postgres")
parser.add_argument('--db', help="database name for postgres")
parser.add_argument('--table_name', help="name of the table where we will write the results to")
parser.add_argument('--url', help="url of the csv file")
# Out:
# _StoreAction(option_strings=['--url'], dest='url', nargs=None, const=None, default=None, type=None, choices=None, required=False, help='url of the csv file', metavar=None)
